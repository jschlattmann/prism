-- %%
--CREATE OR REPLACE TABLE teamconnect.pca_prism.04_tbl_base_btns AS
INSERT OVERWRITE TABLE teamconnect.pca_prism.04_tbl_base_btns
SELECT btn, dpi_environment FROM teamconnect.pca_prism.05_tbl_account_prism_sub_trt_prm
UNION DISTINCT
SELECT btn, dpi_environment FROM teamconnect.pca_prism.01_tbl_account_prism_payments
UNION DISTINCT
SELECT btn, dpi_environment FROM teamconnect.pca_prism.02_tbl_account_prism_services;
